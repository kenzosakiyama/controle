# %%
from control import *
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20,10)

# %% [markdown]
# # Ex1 : Parametros especificados
# - zeta = 0.5, atenuação <= 3 e erro estático de posição nulo

# %%
C = 68.63 * TransferFunction([1, 3], [1, 10.2])
C
# Out:
# 68.63 s + 205.9
# ---------------
#     s + 10.2

# %%
G = TransferFunction([1], [1, 1, 0])
G
# Out:
#    1
# -------
# s^2 + s

# %%
interval = np.linspace(0, 10, 1000)
t, y = step_response(C*G / (1 + C*G), interval)

# %%
# Resposta ao degrau
plt.plot(t, y)
plt.xlabel("time (s)")
plt.ylabel("amplitude")
plt.grid()

# %% [markdown]
# # Ex2:
# - Mp <= 16% e ts <= 0.6s (critério 5%)

# %%
G = TransferFunction([10], [1, 0.1, 0])
G
# Out:
#     10
# -----------
# s^2 + 0.1 s

# %%
C = 7.72 * TransferFunction([1, 2], [1, 13.84])
C
# Out:
# 7.72 s + 15.44
# --------------
#   s + 13.84

# %%
t, y = step_response(C*G / (1 + C*G), interval)

# %%
# Resposta ao degrau
plt.plot(t, y)
plt.xlabel("time (s)")
plt.ylabel("amplitude")
plt.grid()

# %% [markdown]
# # Ex2:
# - ts <= 2s (critério 5%), Mp <= 10%, Erro estático de posição nulo (cumprido pela planta)

# %%
C = 23.96 * TransferFunction([1, 4], [1, 8])
# C = 123.8 * TransferFunction([1, 3.5], [1, 14.4])
C
# Out:
# 23.96 s + 95.84
# ---------------
#      s + 8

# %%
G = TransferFunction([1], [1, 2, 0])
G
# Out:
#     1
# ---------
# s^2 + 2 s

# %%
t, y = step_response(C*G / (1 + C*G), interval)

# %%
# Resposta ao degrau
plt.plot(t, y)
plt.xlabel("time (s)")
plt.ylabel("amplitude")
plt.grid()

# %% [markdown]
# # Ex3:
# - Erro estático de posição nulo, ts <= 1s (critério 2%), Mp <= 10% e dominancia de 2 ordem

# %%
C = 0.24 * TransferFunction([1, 3], [1, 16.03])
# C = 0.76 * TransferFunction([1, 5], [1, 50])
C
# Out:
# 0.24 s + 0.72
# -------------
#   s + 16.03

# %%
G = TransferFunction([500], [1, 0, 0])
G
# Out:
# 500
# ---
# s^2

# %%
t, y = step_response(C*G / (1 + C*G), interval)

# %%
# Resposta ao degrau
plt.plot(t, y)
plt.xlabel("time (s)")
plt.ylabel("amplitude")
plt.grid()

# %% [markdown]
# # Ex4:
# - Mp <= 16% e ts < 1s (critério 2%)

# %%
C = 3.54 * TransferFunction([1, 3], [1, 11.86])
# C = 2 * TransferFunction([1, 2], [1, 10.3])
C
# Out:
# 3.54 s + 10.62
# --------------
#   s + 11.86

# %%
G = TransferFunction([20], [1, 2, 5])
G
# Out:
#       20
# -------------
# s^2 + 2 s + 5

# %%
t, y = step_response(C*G / (1 + C*G), interval)

# %%
# Resposta ao degrau
plt.plot(t, y)
plt.xlabel("time (s)")
plt.ylabel("amplitude")
plt.grid()

# %% [markdown]
# # Ex: Efeito de zeros imaginários

# %%
G = TransferFunction([1, 2, 2], [1, 5, 6])
G
# Out:
# s^2 + 2 s + 2
# -------------
# s^2 + 5 s + 6

# %%
_ = root_locus(G, kvect=np.linspace(0, 7, 100), xlim=(-5, 5), ylim=(-5, 5))

# %%
t, y = step_response(G / (1 + G), interval)
