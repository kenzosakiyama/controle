# %%
import control as co
import numpy as np
import matplotlib.pyplot as plt
# plt.rcParams["figure.figsize"] = (20,10)

# %%
demo = co.TransferFunction([1], [1,3,2])

# %%
demo
# Out:
#       1
# -------------
# s^2 + 3 s + 2

# %%
_ = co.nyquist_plot(demo)
