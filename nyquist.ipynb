# %%
import control as co
import numpy as np
import matplotlib.pyplot as plt
# plt.rcParams["figure.figsize"] = (20,10)

# %%
demo = co.TransferFunction([1, 1], [1,0.8,1])

# %%
demo
# Out:
#      s + 1
# ---------------
# s^2 + 0.8 s + 1

# %%
_ = co.nyquist_plot(-1*demo)

# %%
G = co.TransferFunction([4, 1], [5, 1, 0, 0])

# %%
G
# Out:
#   4 s + 1
# -----------
# 5 s^3 + s^2

# %%
_ = co.nyquist_plot(G)
