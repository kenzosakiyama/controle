# %%
from control import *
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20,10)

# %%
example = TransferFunction([1], [1, 1]) * TransferFunction([1], [1, -2])

# %%
example
# Out:
#      1
# -----------
# s^2 - s - 2

# %%
_ = root_locus(example, kvect=np.linspace(0, 10, 10))

# %%
x_array, y_array = impulse_response(example)

# %%
plt.plot(x_array, y_array)
plt.xlabel("time (s)")
plt.ylabel("amplitude")
plt.grid()
