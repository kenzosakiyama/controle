# %%
import control as co
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20,10)

# %% [markdown]
# # Integrador

# %%
integrator = co.tf([1], [1, 0, 0])

# %%
integrator
# Out:
#  1
# ---
# s^2

# %%
interval = np.linspace(0, 10, 1000)

# %%
t1, y1 = co.impulse_response(integrator, interval)

# %%
plt.plot(t1, y1)
plt.xlabel("time (s)")
plt.ylabel("amplitude")
plt.grid()

# %%
_, _, _ = co.bode_plot(integrator)

# %% [markdown]
# # Exemplos

# %%
G = co.tf([1], [1, 0.1, 0])
G
# Out:
#      1
# -----------
# s^2 + 0.1 s

# %%
_, _, _ = co.bode_plot(0.01*G, dB=True, omega_limits=(10e-3, 10e3), margins=True)
